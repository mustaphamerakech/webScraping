# %%
import requests
from bs4 import BeautifulSoup
import time

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}
html_text = requests.get('https://www.emploitic.com/offres-d-emploi', headers=headers).text
# print(html_text)

# %%
soup = BeautifulSoup(html_text, 'html.parser')
jobs = soup.find_all('li', class_ ='separator-bot')
jobs
# Out:
# [<li class="separator-bot">
#  <!--<ul class="share-list hidden-phone">
#  		<li class="share-featured" onClick="" data-toggle="modal" data-target="#loginModal"><i class="fa fa-star"></i><span class="text">Sauvegarder</span></li>
#                  <li class="share-mail"><span class="text"><a class="color-a" href="mailto:?subject=Annonce consultée sur Emploitic.com - Coordinateur Trésorerie et Relations Bancaires&body=Bonjour,%0D%0A%0D%0AVoici une annonce d’Emploitic.com qui me semble intéressante : Coordinateur Trésorerie et Relations Bancaires : https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/bab-el-oued/10076659-coordinateur-tresorerie-et-relations-bancaires">Envoyer par mail</a></span><i class="fa fa-envelope-o"></i></li>
#          <li class="share-sn">
#              <i class="fa fa-mail-forward"></i>
#              <span class="text">
#                  <a href="http://www.facebook.com/sharer/sharer.php?s=100&p[url]=https%3A%2F%2Fwww.emploitic.com%2F%2Foffres-d-emploi%2Foffre-d-emploi%2Falgerie%2Falger%2Fbab-el-oued%2F10076659-coordinateur-tresorerie-et-relations-bancaires&p[title]=Coordinateur Trésorerie et Relations Bancaires" class="jbshare"><i class="fa fa-facebook icon-wide"></i> </a>
#  <a href="http://www.linkedin.com/shareArticle?mini=true&url=https%3A%2F%2Fwww.emploitic.com%2F%2Foffres-d-emploi%2Foffre-d-emploi%2Falgerie%2Falger%2Fbab-el-oued%2F10076659-coordinateur-tresorerie-et-relations-bancaires&title=Coordinateur Trésorerie et Relations Bancaires" class="jbshare"><i class="fa fa-linkedin icon-wide"></i> </a>
#  <a href="http://twitter.com/home?status=https%3A%2F%2Fwww.emploitic.com%2F%2Foffres-d-emploi%2Foffre-d-emploi%2Falgerie%2Falger%2Fbab-el-oued%2F10076659-coordinateur-tresorerie-et-relations-bancaires&title=Coordinateur Trésorerie et Relations Bancaires" class="jbshare"><i class="fa fa-twitter icon-wide"></i> </a>
#
#  <script>
#      jQuery(document).ready(function(){
#      	jQuery('.jbshare').click(function(){
#      		var url = this.href;
#      		window.open(url,'popUpWindow','height=375px,width=500px,left=300,top=200,resizable=yes,scrollbars=yes,toolbar=no,menubar=no,location=no,directories=no,status=no');return false;
#      	})
#      });
#  </script>            </span>
#          </li>
#  	</ul>-->
#  <div class="row-fluid job-details pointer">
#  <div class="bloc-right" onclick="document.location.href = 'https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/bab-el-oued/10076659-coordinateur-tresorerie-et-relations-bancaires'; return false">
#  <div class="left-bloc text-center" itemprop="logo" itemtype="http://schema.org/Organization">
#  <img alt="Entreprise anonyme - Coordinateur Trésorerie et Relations Bancaires" class="has-radius" height="50" src="https://www.emploitic.com/attachments/company_logo/logo_5512475_large.jpg" width="80"/>
#  </div>
#  <div class="row-fluid">
#  <a href="https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/bab-el-oued/10076659-coordinateur-tresorerie-et-relations-bancaires" title="Coordinateur Trésorerie et Relations Bancaires">
#  <h2 class="ellipsis row-fluid">
#                          Coordinateur Trésorerie et Relations Bancaires                    </h2>
#  </a>
#  <div class="contact">
#  <h6 class="ellipsis"><span>Entreprise anonyme</span></h6>
#  </div>
#  </div>
#  </div>
#  <div class="row-fluid" onclick="document.location.href = 'https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/bab-el-oued/10076659-coordinateur-tresorerie-et-relations-bancaires'; return false">
#  <div class="bloc-bottom phone-text-small">
#  <span class="pull-left"><span class="spaced-right"><i class="fa fa-map-marker icon-left"></i>Bab El Oued, Alger, Algérie...</span></span>
#  <span class="spaced-right pull-left"><i class="fa fa-clock-o icon-left"></i> Aujourd'hui</span>
#  <span class="spaced-right phone-display-blok"><i class="fa fa-bookmark icon-left"></i> Responsable d'équipe (<span>Plus de 10 ans</span>)</span>
#  </div>
#  </div>
#  <div class="right-bloc hidden-phone">
#  <a class="btn btn-iconed external-link" href="https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/bab-el-oued/10076659-coordinateur-tresorerie-et-relations-bancaires" target="_blank" title="Coordinateur Trésorerie et Relations Bancaires"><i class="fa fa-external-link"></i></a>
#  <!-- <div>
#               <a class="btn btn-small btn-color-a" href="/" title=""></a>
#              </div> -->
#  </div>
#  </div>
#  </li>,
#  <li class="separator-bot">
#  <!--<ul class="share-list hidden-phone">
#  		<li class="share-featured" onClick="" data-toggle="modal" data-target="#loginModal"><i class="fa fa-star"></i><span class="text">Sauvegarder</span></li>
#                  <li class="share-mail"><span class="text"><a class="color-a" href="mailto:?subject=Annonce consultée sur Emploitic.com - Directeur des Ressources Humaines&body=Bonjour,%0D%0A%0D%0AVoici une annonce d’Emploitic.com qui me semble intéressante : Directeur des Ressources Humaines : https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/10076658-directeur-des-ressources-humaines">Envoyer par mail</a></span><i class="fa fa-envelope-o"></i></li>
#          <li class="share-sn">
#              <i class="fa fa-mail-forward"></i>
#              <span class="text">
#                  <a href="http://www.facebook.com/sharer/sharer.php?s=100&p[url]=https%3A%2F%2Fwww.emploitic.com%2F%2Foffres-d-emploi%2Foffre-d-emploi%2Falgerie%2Falger%2F10076658-directeur-des-ressources-humaines&p[title]=Directeur des Ressources Humaines" class="jbshare"><i class="fa fa-facebook icon-wide"></i> </a>
#  <a href="http://www.linkedin.com/shareArticle?mini=true&url=https%3A%2F%2Fwww.emploitic.com%2F%2Foffres-d-emploi%2Foffre-d-emploi%2Falgerie%2Falger%2F10076658-directeur-des-ressources-humaines&title=Directeur des Ressources Humaines" class="jbshare"><i class="fa fa-linkedin icon-wide"></i> </a>
#  <a href="http://twitter.com/home?status=https%3A%2F%2Fwww.emploitic.com%2F%2Foffres-d-emploi%2Foffre-d-emploi%2Falgerie%2Falger%2F10076658-directeur-des-ressources-humaines&title=Directeur des Ressources Humaines" class="jbshare"><i class="fa fa-twitter icon-wide"></i> </a>
#
#  <script>
#      jQuery(document).ready(function(){
#      	jQuery('.jbshare').click(function(){
#      		var url = this.href;
#      		window.open(url,'popUpWindow','height=375px,width=500px,left=300,top=200,resizable=yes,scrollbars=yes,toolbar=no,menubar=no,location=no,directories=no,status=no');return false;
#      	})
#      });
#  </script>            </span>
#          </li>
#  	</ul>-->
#  <div class="row-fluid job-details pointer">
#  <div class="bloc-right" onclick="document.location.href = 'https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/10076658-directeur-des-ressources-humaines'; return false">
#  <div class="left-bloc text-center" itemprop="logo" itemtype="http://schema.org/Organization">
#  <img alt="eTalent Solutions - Directeur des Ressources Humaines" class="has-radius" height="50" src="https://www.emploitic.com/attachments/company_logo/logo_5512162_large.jpg" width="80"/>
#  </div>
#  <div class="row-fluid">
#  <a href="https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/10076658-directeur-des-ressources-humaines" title="Directeur des Ressources Humaines">
#  <h2 class="ellipsis row-fluid">
#                          Directeur des Ressources Humaines                    </h2>
#  </a>
#  <div class="contact">
#  <h6 class="ellipsis"><span>eTalent Solutions</span></h6>
#  </div>
#  </div>
#  </div>
#  <div class="row-fluid" onclick="document.location.href = 'https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/10076658-directeur-des-ressources-humaines'; return false">
#  <div class="bloc-bottom phone-text-small">
#  <span class="pull-left"><span class="spaced-right"><i class="fa fa-map-marker icon-left"></i>Alger, Algérie</span></span>
#  <span class="spaced-right pull-left"><i class="fa fa-clock-o icon-left"></i> Hier</span>
#  <span class="spaced-right phone-display-blok"><i class="fa fa-bookmark icon-left"></i> Cadre dirigeant (<span>Plus de 10 ans</span>)</span>
#  </div>
#  </div>
#  <div class="right-bloc hidden-phone">
#  <a class="btn btn-iconed external-link" href="https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/10076658-directeur-des-ressources-humaines" target="_blank" title="Directeur des Ressources Humaines"><i class="fa fa-external-link"></i></a>
#  <!-- <div>
#               <a class="btn btn-small btn-color-a" href="/" title=""></a>
#              </div> -->
#  </div>
#  </div>
#  </li>,
#  <li class="separator-bot">
#  <!--<ul class="share-list hidden-phone">
#  		<li class="share-featured" onClick="" data-toggle="modal" data-target="#loginModal"><i class="fa fa-star"></i><span class="text">Sauvegarder</span></li>
#                  <li class="share-mail"><span class="text"><a class="color-a" href="mailto:?subject=Annonce consultée sur Emploitic.com - Chef d'Antenne Commercial&body=Bonjour,%0D%0A%0D%0AVoici une annonce d’Emploitic.com qui me semble intéressante : Chef d'Antenne Commercial : https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/oran/oran/10074852-chef-d-antenne-commercial">Envoyer par mail</a></span><i class="fa fa-envelope-o"></i></li>
#          <li class="share-sn">
#              <i class="fa fa-mail-forward"></i>
#              <span class="text">
#                  <a href="http://www.facebook.com/sharer/sharer.php?s=100&p[url]=https%3A%2F%2Fwww.emploitic.com%2F%2Foffres-d-emploi%2Foffre-d-emploi%2Falgerie%2Foran%2Foran%2F10074852-chef-d-antenne-commercial&p[title]=Chef d'Antenne Commercial" class="jbshare"><i class="fa fa-facebook icon-wide"></i> </a>
#  <a href="http://www.linkedin.com/shareArticle?mini=true&url=https%3A%2F%2Fwww.emploitic.com%2F%2Foffres-d-emploi%2Foffre-d-emploi%2Falgerie%2Foran%2Foran%2F10074852-chef-d-antenne-commercial&title=Chef d'Antenne Commercial" class="jbshare"><i class="fa fa-linkedin icon-wide"></i> </a>
#  <a href="http://twitter.com/home?status=https%3A%2F%2Fwww.emploitic.com%2F%2Foffres-d-emploi%2Foffre-d-emploi%2Falgerie%2Foran%2Foran%2F10074852-chef-d-antenne-commercial&title=Chef d'Antenne Commercial" class="jbshare"><i class="fa fa-twitter icon-wide"></i> </a>
#
#  <script>
#      jQuery(document).ready(function(){
#      	jQuery('.jbshare').click(function(){
#      		var url = this.href;
#      		window.open(url,'popUpWindow','height=375px,width=500px,left=300,top=200,resizable=yes,scrollbars=yes,toolbar=no,menubar=no,location=no,directories=no,status=no');return false;
#      	})
#      });
#  </script>            </span>
#          </li>
#  	</ul>-->
#  <div class="row-fluid job-details pointer">
#  <div class="bloc-right" onclick="document.location.href = 'https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/oran/oran/10074852-chef-d-antenne-commercial'; return false">
#  <div class="left-bloc text-center" itemprop="logo" itemtype="http://schema.org/Organization">
#  <img alt="Sarl Somafe - Chef d'Antenne Commercial" class="has-radius" height="50" src="https://www.emploitic.com/attachments/company_logo/logo_5512171_large.jpg" width="80"/>
#  </div>
#  <div class="row-fluid">
#  <a href="https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/oran/oran/10074852-chef-d-antenne-commercial" title="Chef d'Antenne Commercial">
#  <h2 class="ellipsis row-fluid">
#                          Chef d'Antenne Commercial                    </h2>
#  </a>
#  <div class="contact">
#  <h6 class="ellipsis"><span>Sarl Somafe</span></h6>
#  </div>
#  </div>
#  </div>
#  <div class="row-fluid" onclick="document.location.href = 'https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/oran/oran/10074852-chef-d-antenne-commercial'; return false">
#  <div class="bloc-bottom phone-text-small">
#  <span class="pull-left"><span class="spaced-right"><i class="fa fa-map-marker icon-left"></i>Oran, Oran, Algérie</span></span>
#  <span class="spaced-right pull-left"><i class="fa fa-clock-o icon-left"></i> Hier</span>
#  <span class="spaced-right phone-display-blok"><i class="fa fa-bookmark icon-left"></i> Manager / Responsable département (<span>Plus de 10 ans</span>)</span>
#  </div>
#  </div>
#  <div class="right-bloc hidden-phone">
#  <a class="btn btn-iconed external-link" href="https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/oran/oran/10074852-chef-d-antenne-commercial" target="_blank" title="Chef d'Antenne Commercial"><i class="fa fa-external-link"></i></a>
#  <!-- <div>
#               <a class="btn btn-small btn-color-a" href="/" title=""></a>
#              </div> -->
#  </div>
#  </div>
#  </li>,
#  <li class="separator-bot">
#  <!--<ul class="share-list hidden-phone">
#  		<li class="share-featured" onClick="" data-toggle="modal" data-target="#loginModal"><i class="fa fa-star"></i><span class="text">Sauvegarder</span></li>
#                  <li class="share-mail"><span class="text"><a class="color-a" href="mailto:?subject=Annonce consultée sur Emploitic.com - Responsable Maintenance Auxiliaire&body=Bonjour,%0D%0A%0D%0AVoici une annonce d’Emploitic.com qui me semble intéressante : Responsable Maintenance Auxiliaire : https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/10076657-responsable-maintenance-auxiliaire">Envoyer par mail</a></span><i class="fa fa-envelope-o"></i></li>
#          <li class="share-sn">
#              <i class="fa fa-mail-forward"></i>
#              <span class="text">
#                  <a href="http://www.facebook.com/sharer/sharer.php?s=100&p[url]=https%3A%2F%2Fwww.emploitic.com%2F%2Foffres-d-emploi%2Foffre-d-emploi%2Falgerie%2Falger%2F10076657-responsable-maintenance-auxiliaire&p[title]=Responsable Maintenance Auxiliaire" class="jbshare"><i class="fa fa-facebook icon-wide"></i> </a>
#  <a href="http://www.linkedin.com/shareArticle?mini=true&url=https%3A%2F%2Fwww.emploitic.com%2F%2Foffres-d-emploi%2Foffre-d-emploi%2Falgerie%2Falger%2F10076657-responsable-maintenance-auxiliaire&title=Responsable Maintenance Auxiliaire" class="jbshare"><i class="fa fa-linkedin icon-wide"></i> </a>
#  <a href="http://twitter.com/home?status=https%3A%2F%2Fwww.emploitic.com%2F%2Foffres-d-emploi%2Foffre-d-emploi%2Falgerie%2Falger%2F10076657-responsable-maintenance-auxiliaire&title=Responsable Maintenance Auxiliaire" class="jbshare"><i class="fa fa-twitter icon-wide"></i> </a>
#
#  <script>
#      jQuery(document).ready(function(){
#      	jQuery('.jbshare').click(function(){
#      		var url = this.href;
#      		window.open(url,'popUpWindow','height=375px,width=500px,left=300,top=200,resizable=yes,scrollbars=yes,toolbar=no,menubar=no,location=no,directories=no,status=no');return false;
#      	})
#      });
#  </script>            </span>
#          </li>
#  	</ul>-->
#  <div class="row-fluid job-details pointer">
#  <div class="bloc-right" onclick="document.location.href = 'https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/10076657-responsable-maintenance-auxiliaire'; return false">
#  <div class="left-bloc text-center" itemprop="logo" itemtype="http://schema.org/Organization">
#  <img alt="Entreprise anonyme - Responsable Maintenance Auxiliaire" class="has-radius" height="50" src="https://www.emploitic.com/attachments/company_logo/logo_5512124_large.jpg" width="80"/>
#  </div>
#  <div class="row-fluid">
#  <a href="https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/10076657-responsable-maintenance-auxiliaire" title="Responsable Maintenance Auxiliaire">
#  <h2 class="ellipsis row-fluid">
#                          Responsable Maintenance Auxiliaire                    </h2>
#  </a>
#  <div class="contact">
#  <h6 class="ellipsis"><span>Entreprise anonyme</span></h6>
#  </div>
#  </div>
#  </div>
#  <div class="row-fluid" onclick="document.location.href = 'https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/10076657-responsable-maintenance-auxiliaire'; return false">
#  <div class="bloc-bottom phone-text-small">
#  <span class="pull-left"><span class="spaced-right"><i class="fa fa-map-marker icon-left"></i>Alger, Algérie</span></span>
#  <span class="spaced-right pull-left"><i class="fa fa-clock-o icon-left"></i> Hier</span>
#  <span class="spaced-right phone-display-blok"><i class="fa fa-bookmark icon-left"></i> Responsable d'équipe (<span>6 à 10 ans</span>)</span>
#  </div>
#  </div>
#  <div class="right-bloc hidden-phone">
#  <a class="btn btn-iconed external-link" href="https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/10076657-responsable-maintenance-auxiliaire" target="_blank" title="Responsable Maintenance Auxiliaire"><i class="fa fa-external-link"></i></a>
#  <!-- <div>
#               <a class="btn btn-small btn-color-a" href="/" title=""></a>
#              </div> -->
#  </div>
#  </div>
#  </li>,
#  <li class="separator-bot">
#  <!--<ul class="share-list hidden-phone">
#  		<li class="share-featured" onClick="" data-toggle="modal" data-target="#loginModal"><i class="fa fa-star"></i><span class="text">Sauvegarder</span></li>
#                  <li class="share-mail"><span class="text"><a class="color-a" href="mailto:?subject=Annonce consultée sur Emploitic.com - coordinature QHSE&body=Bonjour,%0D%0A%0D%0AVoici une annonce d’Emploitic.com qui me semble intéressante : coordinature QHSE : https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/bouira/10076656-coordinature-qhse">Envoyer par mail</a></span><i class="fa fa-envelope-o"></i></li>
#          <li class="share-sn">
#              <i class="fa fa-mail-forward"></i>
#              <span class="text">
#                  <a href="http://www.facebook.com/sharer/sharer.php?s=100&p[url]=https%3A%2F%2Fwww.emploitic.com%2F%2Foffres-d-emploi%2Foffre-d-emploi%2Falgerie%2Fbouira%2F10076656-coordinature-qhse&p[title]=coordinature QHSE" class="jbshare"><i class="fa fa-facebook icon-wide"></i> </a>
#  <a href="http://www.linkedin.com/shareArticle?mini=true&url=https%3A%2F%2Fwww.emploitic.com%2F%2Foffres-d-emploi%2Foffre-d-emploi%2Falgerie%2Fbouira%2F10076656-coordinature-qhse&title=coordinature QHSE" class="jbshare"><i class="fa fa-linkedin icon-wide"></i> </a>
#  <a href="http://twitter.com/home?status=https%3A%2F%2Fwww.emploitic.com%2F%2Foffres-d-emploi%2Foffre-d-emploi%2Falgerie%2Fbouira%2F10076656-coordinature-qhse&title=coordinature QHSE" class="jbshare"><i class="fa fa-twitter icon-wide"></i> </a>
#
#  <script>
#      jQuery(document).ready(function(){
#      	jQuery('.jbshare').click(function(){
#      		var url = this.href;
#      		window.open(url,'popUpWindow','height=375px,width=500px,left=300,top=200,resizable=yes,scrollbars=yes,toolbar=no,menubar=no,location=no,directories=no,status=no');return false;
#      	})
#      });
#  </script>            </span>
#          </li>
#  	</ul>-->
#  <div class="row-fluid job-details pointer">
#  <div class="bloc-right" onclick="document.location.href = 'https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/bouira/10076656-coordinature-qhse'; return false">
#  <div class="left-bloc text-center" itemprop="logo" itemtype="http://schema.org/Organization">
#  <img alt="Entreprise anonyme - coordinature QHSE" class="has-radius" height="50" src="https://www.emploitic.com/attachments/company_logo/logo_5512121_large.jpg" width="80"/>
#  </div>
#  <div class="row-fluid">
#  <a href="https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/bouira/10076656-coordinature-qhse" title="coordinature QHSE">
#  <h2 class="ellipsis row-fluid">
#                          coordinature QHSE                    </h2>
#  </a>
#  <div class="contact">
#  <h6 class="ellipsis"><span>Entreprise anonyme</span></h6>
#  </div>
#  </div>
#  </div>
#  <div class="row-fluid" onclick="document.location.href = 'https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/bouira/10076656-coordinature-qhse'; return false">
#  <div class="bloc-bottom phone-text-small">
#  <span class="pull-left"><span class="spaced-right"><i class="fa fa-map-marker icon-left"></i>Bouira, Algérie</span></span>
#  <span class="spaced-right pull-left"><i class="fa fa-clock-o icon-left"></i> Hier</span>
#  <span class="spaced-right phone-display-blok"><i class="fa fa-bookmark icon-left"></i> Responsable d'équipe (<span>6 à 10 ans</span>)</span>
#  </div>
#  </div>
#  <div class="right-bloc hidden-phone">
#  <a class="btn btn-iconed external-link" href="https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/bouira/10076656-coordinature-qhse" target="_blank" title="coordinature QHSE"><i class="fa fa-external-link"></i></a>
#  <!-- <div>
#               <a class="btn btn-small btn-color-a" href="/" title=""></a>
#              </div> -->
#  </div>
#  </div>
#  </li>,
#  <li class="separator-bot">
#  <!--<ul class="share-list hidden-phone">
#  		<li class="share-featured" onClick="" data-toggle="modal" data-target="#loginModal"><i class="fa fa-star"></i><span class="text">Sauvegarder</span></li>
#                  <li class="share-mail"><span class="text"><a class="color-a" href="mailto:?subject=Annonce consultée sur Emploitic.com - Cadre Planning   &body=Bonjour,%0D%0A%0D%0AVoici une annonce d’Emploitic.com qui me semble intéressante : Cadre Planning    : https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/10076653-cadre-planning">Envoyer par mail</a></span><i class="fa fa-envelope-o"></i></li>
#          <li class="share-sn">
#              <i class="fa fa-mail-forward"></i>
#              <span class="text">
#                  <a href="http://www.facebook.com/sharer/sharer.php?s=100&p[url]=https%3A%2F%2Fwww.emploitic.com%2F%2Foffres-d-emploi%2Foffre-d-emploi%2Falgerie%2Falger%2F10076653-cadre-planning&p[title]=Cadre Planning   " class="jbshare"><i class="fa fa-facebook icon-wide"></i> </a>
#  <a href="http://www.linkedin.com/shareArticle?mini=true&url=https%3A%2F%2Fwww.emploitic.com%2F%2Foffres-d-emploi%2Foffre-d-emploi%2Falgerie%2Falger%2F10076653-cadre-planning&title=Cadre Planning   " class="jbshare"><i class="fa fa-linkedin icon-wide"></i> </a>
#  <a href="http://twitter.com/home?status=https%3A%2F%2Fwww.emploitic.com%2F%2Foffres-d-emploi%2Foffre-d-emploi%2Falgerie%2Falger%2F10076653-cadre-planning&title=Cadre Planning   " class="jbshare"><i class="fa fa-twitter icon-wide"></i> </a>
#
#  <script>
#      jQuery(document).ready(function(){
#      	jQuery('.jbshare').click(function(){
#      		var url = this.href;
#      		window.open(url,'popUpWindow','height=375px,width=500px,left=300,top=200,resizable=yes,scrollbars=yes,toolbar=no,menubar=no,location=no,directories=no,status=no');return false;
#      	})
#      });
#  </script>            </span>
#          </li>
#  	</ul>-->
#  <div class="row-fluid job-details pointer">
#  <div class="bloc-right" onclick="document.location.href = 'https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/10076653-cadre-planning'; return false">
#  <div class="left-bloc text-center" itemprop="logo" itemtype="http://schema.org/Organization">
#  <img alt="Entreprise anonyme - Cadre Planning   " class="has-radius" height="50" src="https://www.emploitic.com/attachments/company_logo/logo_5512122_large.jpg" width="80"/>
#  </div>
#  <div class="row-fluid">
#  <a href="https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/10076653-cadre-planning" title="Cadre Planning   ">
#  <h2 class="ellipsis row-fluid">
#                          Cadre Planning                       </h2>
#  </a>
#  <div class="contact">
#  <h6 class="ellipsis"><span>Entreprise anonyme</span></h6>
#  </div>
#  </div>
#  </div>
#  <div class="row-fluid" onclick="document.location.href = 'https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/10076653-cadre-planning'; return false">
#  <div class="bloc-bottom phone-text-small">
#  <span class="pull-left"><span class="spaced-right"><i class="fa fa-map-marker icon-left"></i>Alger, Algérie</span></span>
#  <span class="spaced-right pull-left"><i class="fa fa-clock-o icon-left"></i> Hier</span>
#  <span class="spaced-right phone-display-blok"><i class="fa fa-bookmark icon-left"></i> Responsable d'équipe (<span>Plus de 10 ans</span>)</span>
#  </div>
#  </div>
#  <div class="right-bloc hidden-phone">
#  <a class="btn btn-iconed external-link" href="https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/10076653-cadre-planning" target="_blank" title="Cadre Planning   "><i class="fa fa-external-link"></i></a>
#  <!-- <div>
#               <a class="btn btn-small btn-color-a" href="/" title=""></a>
#              </div> -->
#  </div>
#  </div>
#  </li>,
#  <li class="separator-bot">
#  <!--<ul class="share-list hidden-phone">
#  		<li class="share-featured" onClick="" data-toggle="modal" data-target="#loginModal"><i class="fa fa-star"></i><span class="text">Sauvegarder</span></li>
#                  <li class="share-mail"><span class="text"><a class="color-a" href="mailto:?subject=Annonce consultée sur Emploitic.com - Responsable Maintenance engins et camions&body=Bonjour,%0D%0A%0D%0AVoici une annonce d’Emploitic.com qui me semble intéressante : Responsable Maintenance engins et camions : https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/10076651-responsable-maintenance-engins-et-camions">Envoyer par mail</a></span><i class="fa fa-envelope-o"></i></li>
#          <li class="share-sn">
#              <i class="fa fa-mail-forward"></i>
#              <span class="text">
#                  <a href="http://www.facebook.com/sharer/sharer.php?s=100&p[url]=https%3A%2F%2Fwww.emploitic.com%2F%2Foffres-d-emploi%2Foffre-d-emploi%2Falgerie%2Falger%2F10076651-responsable-maintenance-engins-et-camions&p[title]=Responsable Maintenance engins et camions" class="jbshare"><i class="fa fa-facebook icon-wide"></i> </a>
#  <a href="http://www.linkedin.com/shareArticle?mini=true&url=https%3A%2F%2Fwww.emploitic.com%2F%2Foffres-d-emploi%2Foffre-d-emploi%2Falgerie%2Falger%2F10076651-responsable-maintenance-engins-et-camions&title=Responsable Maintenance engins et camions" class="jbshare"><i class="fa fa-linkedin icon-wide"></i> </a>
#  <a href="http://twitter.com/home?status=https%3A%2F%2Fwww.emploitic.com%2F%2Foffres-d-emploi%2Foffre-d-emploi%2Falgerie%2Falger%2F10076651-responsable-maintenance-engins-et-camions&title=Responsable Maintenance engins et camions" class="jbshare"><i class="fa fa-twitter icon-wide"></i> </a>
#
#  <script>
#      jQuery(document).ready(function(){
#      	jQuery('.jbshare').click(function(){
#      		var url = this.href;
#      		window.open(url,'popUpWindow','height=375px,width=500px,left=300,top=200,resizable=yes,scrollbars=yes,toolbar=no,menubar=no,location=no,directories=no,status=no');return false;
#      	})
#      });
#  </script>            </span>
#          </li>
#  	</ul>-->
#  <div class="row-fluid job-details pointer">
#  <div class="bloc-right" onclick="document.location.href = 'https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/10076651-responsable-maintenance-engins-et-camions'; return false">
#  <div class="left-bloc text-center" itemprop="logo" itemtype="http://schema.org/Organization">
#  <img alt="Entreprise anonyme - Responsable Maintenance engins et camions" class="has-radius" height="50" src="https://www.emploitic.com/attachments/company_logo/logo_5512089_large.jpg" width="80"/>
#  </div>
#  <div class="row-fluid">
#  <a href="https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/10076651-responsable-maintenance-engins-et-camions" title="Responsable Maintenance engins et camions">
#  <h2 class="ellipsis row-fluid">
#                          Responsable Maintenance engins et camions                    </h2>
#  </a>
#  <div class="contact">
#  <h6 class="ellipsis"><span>Entreprise anonyme</span></h6>
#  </div>
#  </div>
#  </div>
#  <div class="row-fluid" onclick="document.location.href = 'https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/10076651-responsable-maintenance-engins-et-camions'; return false">
#  <div class="bloc-bottom phone-text-small">
#  <span class="pull-left"><span class="spaced-right"><i class="fa fa-map-marker icon-left"></i>Alger, Algérie</span></span>
#  <span class="spaced-right pull-left"><i class="fa fa-clock-o icon-left"></i> Hier</span>
#  <span class="spaced-right phone-display-blok"><i class="fa fa-bookmark icon-left"></i> Responsable d'équipe (<span>6 à 10 ans</span>)</span>
#  </div>
#  </div>
#  <div class="right-bloc hidden-phone">
#  <a class="btn btn-iconed external-link" href="https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/10076651-responsable-maintenance-engins-et-camions" target="_blank" title="Responsable Maintenance engins et camions"><i class="fa fa-external-link"></i></a>
#  <!-- <div>
#               <a class="btn btn-small btn-color-a" href="/" title=""></a>
#              </div> -->
#  </div>
#  </div>
#  </li>,
#  <li class="separator-bot">
#  <!--<ul class="share-list hidden-phone">
#  		<li class="share-featured" onClick="" data-toggle="modal" data-target="#loginModal"><i class="fa fa-star"></i><span class="text">Sauvegarder</span></li>
#                  <li class="share-mail"><span class="text"><a class="color-a" href="mailto:?subject=Annonce consultée sur Emploitic.com - Responsable Entrepot&body=Bonjour,%0D%0A%0D%0AVoici une annonce d’Emploitic.com qui me semble intéressante : Responsable Entrepot : https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/10076650-responsable-entrepot">Envoyer par mail</a></span><i class="fa fa-envelope-o"></i></li>
#          <li class="share-sn">
#              <i class="fa fa-mail-forward"></i>
#              <span class="text">
#                  <a href="http://www.facebook.com/sharer/sharer.php?s=100&p[url]=https%3A%2F%2Fwww.emploitic.com%2F%2Foffres-d-emploi%2Foffre-d-emploi%2Falgerie%2Falger%2F10076650-responsable-entrepot&p[title]=Responsable Entrepot" class="jbshare"><i class="fa fa-facebook icon-wide"></i> </a>
#  <a href="http://www.linkedin.com/shareArticle?mini=true&url=https%3A%2F%2Fwww.emploitic.com%2F%2Foffres-d-emploi%2Foffre-d-emploi%2Falgerie%2Falger%2F10076650-responsable-entrepot&title=Responsable Entrepot" class="jbshare"><i class="fa fa-linkedin icon-wide"></i> </a>
#  <a href="http://twitter.com/home?status=https%3A%2F%2Fwww.emploitic.com%2F%2Foffres-d-emploi%2Foffre-d-emploi%2Falgerie%2Falger%2F10076650-responsable-entrepot&title=Responsable Entrepot" class="jbshare"><i class="fa fa-twitter icon-wide"></i> </a>
#
#  <script>
#      jQuery(document).ready(function(){
#      	jQuery('.jbshare').click(function(){
#      		var url = this.href;
#      		window.open(url,'popUpWindow','height=375px,width=500px,left=300,top=200,resizable=yes,scrollbars=yes,toolbar=no,menubar=no,location=no,directories=no,status=no');return false;
#      	})
#      });
#  </script>            </span>
#          </li>
#  	</ul>-->
#  <div class="row-fluid job-details pointer">
#  <div class="bloc-right" onclick="document.location.href = 'https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/10076650-responsable-entrepot'; return false">
#  <div class="left-bloc text-center" itemprop="logo" itemtype="http://schema.org/Organization">
#  <img alt="Entreprise anonyme - Responsable Entrepot" class="has-radius" height="50" src="https://www.emploitic.com/attachments/company_logo/logo_5512072_large.jpg" width="80"/>
#  </div>
#  <div class="row-fluid">
#  <a href="https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/10076650-responsable-entrepot" title="Responsable Entrepot">
#  <h2 class="ellipsis row-fluid">
#                          Responsable Entrepot                    </h2>
#  </a>
#  <div class="contact">
#  <h6 class="ellipsis"><span>Entreprise anonyme</span></h6>
#  </div>
#  </div>
#  </div>
#  <div class="row-fluid" onclick="document.location.href = 'https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/10076650-responsable-entrepot'; return false">
#  <div class="bloc-bottom phone-text-small">
#  <span class="pull-left"><span class="spaced-right"><i class="fa fa-map-marker icon-left"></i>Alger, Algérie</span></span>
#  <span class="spaced-right pull-left"><i class="fa fa-clock-o icon-left"></i> Hier</span>
#  <span class="spaced-right phone-display-blok"><i class="fa fa-bookmark icon-left"></i> Responsable d'équipe (<span>6 à 10 ans</span>)</span>
#  </div>
#  </div>
#  <div class="right-bloc hidden-phone">
#  <a class="btn btn-iconed external-link" href="https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/10076650-responsable-entrepot" target="_blank" title="Responsable Entrepot"><i class="fa fa-external-link"></i></a>
#  <!-- <div>
#               <a class="btn btn-small btn-color-a" href="/" title=""></a>
#              </div> -->
#  </div>
#  </div>
#  </li>,
#  <li class="separator-bot">
#  <!--<ul class="share-list hidden-phone">
#  		<li class="share-featured" onClick="" data-toggle="modal" data-target="#loginModal"><i class="fa fa-star"></i><span class="text">Sauvegarder</span></li>
#                  <li class="share-mail"><span class="text"><a class="color-a" href="mailto:?subject=Annonce consultée sur Emploitic.com - Une Assistante de Direction Générale  (Assistante auprès du PDG Groupe)&body=Bonjour,%0D%0A%0D%0AVoici une annonce d’Emploitic.com qui me semble intéressante : Une Assistante de Direction Générale  (Assistante auprès du PDG Groupe) : https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/alger-centre/10076649-une-assistante-de-direction-generale-assistante-aupres-du-pdg-groupe">Envoyer par mail</a></span><i class="fa fa-envelope-o"></i></li>
#          <li class="share-sn">
#              <i class="fa fa-mail-forward"></i>
#              <span class="text">
#                  <a href="http://www.facebook.com/sharer/sharer.php?s=100&p[url]=https%3A%2F%2Fwww.emploitic.com%2F%2Foffres-d-emploi%2Foffre-d-emploi%2Falgerie%2Falger%2Falger-centre%2F10076649-une-assistante-de-direction-generale-assistante-aupres-du-pdg-groupe&p[title]=Une Assistante de Direction Générale  (Assistante auprès du PDG Groupe)" class="jbshare"><i class="fa fa-facebook icon-wide"></i> </a>
#  <a href="http://www.linkedin.com/shareArticle?mini=true&url=https%3A%2F%2Fwww.emploitic.com%2F%2Foffres-d-emploi%2Foffre-d-emploi%2Falgerie%2Falger%2Falger-centre%2F10076649-une-assistante-de-direction-generale-assistante-aupres-du-pdg-groupe&title=Une Assistante de Direction Générale  (Assistante auprès du PDG Groupe)" class="jbshare"><i class="fa fa-linkedin icon-wide"></i> </a>
#  <a href="http://twitter.com/home?status=https%3A%2F%2Fwww.emploitic.com%2F%2Foffres-d-emploi%2Foffre-d-emploi%2Falgerie%2Falger%2Falger-centre%2F10076649-une-assistante-de-direction-generale-assistante-aupres-du-pdg-groupe&title=Une Assistante de Direction Générale  (Assistante auprès du PDG Groupe)" class="jbshare"><i class="fa fa-twitter icon-wide"></i> </a>
#
#  <script>
#      jQuery(document).ready(function(){
#      	jQuery('.jbshare').click(function(){
#      		var url = this.href;
#      		window.open(url,'popUpWindow','height=375px,width=500px,left=300,top=200,resizable=yes,scrollbars=yes,toolbar=no,menubar=no,location=no,directories=no,status=no');return false;
#      	})
#      });
#  </script>            </span>
#          </li>
#  	</ul>-->
#  <div class="row-fluid job-details pointer">
#  <div class="bloc-right" onclick="document.location.href = 'https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/alger-centre/10076649-une-assistante-de-direction-generale-assistante-aupres-du-pdg-groupe'; return false">
#  <div class="left-bloc text-center" itemprop="logo" itemtype="http://schema.org/Organization">
#  <img alt="Entreprise anonyme - Une Assistante de Direction Générale  (Assistante auprès du PDG Groupe)" class="has-radius" height="50" src="https://www.emploitic.com/attachments/company_logo/logo_5512079_large.jpg" width="80"/>
#  </div>
#  <div class="row-fluid">
#  <a href="https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/alger-centre/10076649-une-assistante-de-direction-generale-assistante-aupres-du-pdg-groupe" title="Une Assistante de Direction Générale  (Assistante auprès du PDG Groupe)">
#  <h2 class="ellipsis row-fluid">
#                          Une Assistante de Direction Générale  (Assistante auprès du PDG Groupe)                    </h2>
#  </a>
#  <div class="contact">
#  <h6 class="ellipsis"><span>Entreprise anonyme</span></h6>
#  </div>
#  </div>
#  </div>
#  <div class="row-fluid" onclick="document.location.href = 'https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/alger-centre/10076649-une-assistante-de-direction-generale-assistante-aupres-du-pdg-groupe'; return false">
#  <div class="bloc-bottom phone-text-small">
#  <span class="pull-left"><span class="spaced-right"><i class="fa fa-map-marker icon-left"></i>Alger Centre, Alger, Algérie</span></span>
#  <span class="spaced-right pull-left"><i class="fa fa-clock-o icon-left"></i> Hier</span>
#  <span class="spaced-right phone-display-blok"><i class="fa fa-bookmark icon-left"></i> Confirmé / Expérimenté (<span>3 à 5 ans</span>)</span>
#  </div>
#  </div>
#  <div class="right-bloc hidden-phone">
#  <a class="btn btn-iconed external-link" href="https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/alger-centre/10076649-une-assistante-de-direction-generale-assistante-aupres-du-pdg-groupe" target="_blank" title="Une Assistante de Direction Générale  (Assistante auprès du PDG Groupe)"><i class="fa fa-external-link"></i></a>
#  <!-- <div>
#               <a class="btn btn-small btn-color-a" href="/" title=""></a>
#              </div> -->
#  </div>
#  </div>
#  </li>,
#  <li class="separator-bot">
#  <!--<ul class="share-list hidden-phone">
#  		<li class="share-featured" onClick="" data-toggle="modal" data-target="#loginModal"><i class="fa fa-star"></i><span class="text">Sauvegarder</span></li>
#                  <li class="share-mail"><span class="text"><a class="color-a" href="mailto:?subject=Annonce consultée sur Emploitic.com - Délégué Pharmaceutique -  BATNA -&body=Bonjour,%0D%0A%0D%0AVoici une annonce d’Emploitic.com qui me semble intéressante : Délégué Pharmaceutique -  BATNA - : https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/batna/10076648-delegue-pharmaceutique-batna">Envoyer par mail</a></span><i class="fa fa-envelope-o"></i></li>
#          <li class="share-sn">
#              <i class="fa fa-mail-forward"></i>
#              <span class="text">
#                  <a href="http://www.facebook.com/sharer/sharer.php?s=100&p[url]=https%3A%2F%2Fwww.emploitic.com%2F%2Foffres-d-emploi%2Foffre-d-emploi%2Falgerie%2Fbatna%2F10076648-delegue-pharmaceutique-batna&p[title]=Délégué Pharmaceutique -  BATNA -" class="jbshare"><i class="fa fa-facebook icon-wide"></i> </a>
#  <a href="http://www.linkedin.com/shareArticle?mini=true&url=https%3A%2F%2Fwww.emploitic.com%2F%2Foffres-d-emploi%2Foffre-d-emploi%2Falgerie%2Fbatna%2F10076648-delegue-pharmaceutique-batna&title=Délégué Pharmaceutique -  BATNA -" class="jbshare"><i class="fa fa-linkedin icon-wide"></i> </a>
#  <a href="http://twitter.com/home?status=https%3A%2F%2Fwww.emploitic.com%2F%2Foffres-d-emploi%2Foffre-d-emploi%2Falgerie%2Fbatna%2F10076648-delegue-pharmaceutique-batna&title=Délégué Pharmaceutique -  BATNA -" class="jbshare"><i class="fa fa-twitter icon-wide"></i> </a>
#
#  <script>
#      jQuery(document).ready(function(){
#      	jQuery('.jbshare').click(function(){
#      		var url = this.href;
#      		window.open(url,'popUpWindow','height=375px,width=500px,left=300,top=200,resizable=yes,scrollbars=yes,toolbar=no,menubar=no,location=no,directories=no,status=no');return false;
#      	})
#      });
#  </script>            </span>
#          </li>
#  	</ul>-->
#  <div class="row-fluid job-details pointer">
#  <div class="bloc-right" onclick="document.location.href = 'https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/batna/10076648-delegue-pharmaceutique-batna'; return false">
#  <div class="left-bloc text-center" itemprop="logo" itemtype="http://schema.org/Organization">
#  <img alt="Pharmalliance - Délégué Pharmaceutique -  BATNA -" class="has-radius" height="50" src="https://www.emploitic.com/attachments/company_logo/logo_5512069_large.jpg" width="80"/>
#  </div>
#  <div class="row-fluid">
#  <a href="https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/batna/10076648-delegue-pharmaceutique-batna" title="Délégué Pharmaceutique -  BATNA -">
#  <h2 class="ellipsis row-fluid">
#                          Délégué Pharmaceutique -  BATNA -                    </h2>
#  </a>
#  <div class="contact">
#  <h6 class="ellipsis"><span>Pharmalliance</span></h6>
#  </div>
#  </div>
#  </div>
#  <div class="row-fluid" onclick="document.location.href = 'https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/batna/10076648-delegue-pharmaceutique-batna'; return false">
#  <div class="bloc-bottom phone-text-small">
#  <span class="pull-left"><span class="spaced-right"><i class="fa fa-map-marker icon-left"></i>Batna, Algérie</span></span>
#  <span class="spaced-right pull-left"><i class="fa fa-clock-o icon-left"></i> Hier</span>
#  <span class="spaced-right phone-display-blok"><i class="fa fa-bookmark icon-left"></i> Confirmé / Expérimenté (<span>3 à 5 ans</span>)</span>
#  </div>
#  </div>
#  <div class="right-bloc hidden-phone">
#  <a class="btn btn-iconed external-link" href="https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/batna/10076648-delegue-pharmaceutique-batna" target="_blank" title="Délégué Pharmaceutique -  BATNA -"><i class="fa fa-external-link"></i></a>
#  <!-- <div>
#               <a class="btn btn-small btn-color-a" href="/" title=""></a>
#              </div> -->
#  </div>
#  </div>
#  </li>,
#  <li class="separator-bot">
#  <!--<ul class="share-list hidden-phone">
#  		<li class="share-featured" onClick="" data-toggle="modal" data-target="#loginModal"><i class="fa fa-star"></i><span class="text">Sauvegarder</span></li>
#                  <li class="share-mail"><span class="text"><a class="color-a" href="mailto:?subject=Annonce consultée sur Emploitic.com - Responsable Entrepôt sous douane&body=Bonjour,%0D%0A%0D%0AVoici une annonce d’Emploitic.com qui me semble intéressante : Responsable Entrepôt sous douane : https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/10076647-responsable-entrepot-sous-douane">Envoyer par mail</a></span><i class="fa fa-envelope-o"></i></li>
#          <li class="share-sn">
#              <i class="fa fa-mail-forward"></i>
#              <span class="text">
#                  <a href="http://www.facebook.com/sharer/sharer.php?s=100&p[url]=https%3A%2F%2Fwww.emploitic.com%2F%2Foffres-d-emploi%2Foffre-d-emploi%2Falgerie%2Falger%2F10076647-responsable-entrepot-sous-douane&p[title]=Responsable Entrepôt sous douane" class="jbshare"><i class="fa fa-facebook icon-wide"></i> </a>
#  <a href="http://www.linkedin.com/shareArticle?mini=true&url=https%3A%2F%2Fwww.emploitic.com%2F%2Foffres-d-emploi%2Foffre-d-emploi%2Falgerie%2Falger%2F10076647-responsable-entrepot-sous-douane&title=Responsable Entrepôt sous douane" class="jbshare"><i class="fa fa-linkedin icon-wide"></i> </a>
#  <a href="http://twitter.com/home?status=https%3A%2F%2Fwww.emploitic.com%2F%2Foffres-d-emploi%2Foffre-d-emploi%2Falgerie%2Falger%2F10076647-responsable-entrepot-sous-douane&title=Responsable Entrepôt sous douane" class="jbshare"><i class="fa fa-twitter icon-wide"></i> </a>
#
#  <script>
#      jQuery(document).ready(function(){
#      	jQuery('.jbshare').click(function(){
#      		var url = this.href;
#      		window.open(url,'popUpWindow','height=375px,width=500px,left=300,top=200,resizable=yes,scrollbars=yes,toolbar=no,menubar=no,location=no,directories=no,status=no');return false;
#      	})
#      });
#  </script>            </span>
#          </li>
#  	</ul>-->
#  <div class="row-fluid job-details pointer">
#  <div class="bloc-right" onclick="document.location.href = 'https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/10076647-responsable-entrepot-sous-douane'; return false">
#  <div class="left-bloc text-center" itemprop="logo" itemtype="http://schema.org/Organization">
#  <img alt="Entreprise anonyme - Responsable Entrepôt sous douane" class="has-radius" height="50" src="https://www.emploitic.com/attachments/company_logo/logo_5512051_large.jpg" width="80"/>
#  </div>
#  <div class="row-fluid">
#  <a href="https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/10076647-responsable-entrepot-sous-douane" title="Responsable Entrepôt sous douane">
#  <h2 class="ellipsis row-fluid">
#                          Responsable Entrepôt sous douane                    </h2>
#  </a>
#  <div class="contact">
#  <h6 class="ellipsis"><span>Entreprise anonyme</span></h6>
#  </div>
#  </div>
#  </div>
#  <div class="row-fluid" onclick="document.location.href = 'https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/10076647-responsable-entrepot-sous-douane'; return false">
#  <div class="bloc-bottom phone-text-small">
#  <span class="pull-left"><span class="spaced-right"><i class="fa fa-map-marker icon-left"></i>Alger, Algérie</span></span>
#  <span class="spaced-right pull-left"><i class="fa fa-clock-o icon-left"></i> Hier</span>
#  <span class="spaced-right phone-display-blok"><i class="fa fa-bookmark icon-left"></i> Responsable d'équipe (<span>6 à 10 ans</span>)</span>
#  </div>
#  </div>
#  <div class="right-bloc hidden-phone">
#  <a class="btn btn-iconed external-link" href="https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/10076647-responsable-entrepot-sous-douane" target="_blank" title="Responsable Entrepôt sous douane"><i class="fa fa-external-link"></i></a>
#  <!-- <div>
#               <a class="btn btn-small btn-color-a" href="/" title=""></a>
#              </div> -->
#  </div>
#  </div>
#  </li>,
#  <li class="separator-bot">
#  <!--<ul class="share-list hidden-phone">
#  		<li class="share-featured" onClick="" data-toggle="modal" data-target="#loginModal"><i class="fa fa-star"></i><span class="text">Sauvegarder</span></li>
#                  <li class="share-mail"><span class="text"><a class="color-a" href="mailto:?subject=Annonce consultée sur Emploitic.com - Responsable Entrepôt sous douane&body=Bonjour,%0D%0A%0D%0AVoici une annonce d’Emploitic.com qui me semble intéressante : Responsable Entrepôt sous douane : https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/10076646-responsable-entrepot-sous-douane">Envoyer par mail</a></span><i class="fa fa-envelope-o"></i></li>
#          <li class="share-sn">
#              <i class="fa fa-mail-forward"></i>
#              <span class="text">
#                  <a href="http://www.facebook.com/sharer/sharer.php?s=100&p[url]=https%3A%2F%2Fwww.emploitic.com%2F%2Foffres-d-emploi%2Foffre-d-emploi%2Falgerie%2Falger%2F10076646-responsable-entrepot-sous-douane&p[title]=Responsable Entrepôt sous douane" class="jbshare"><i class="fa fa-facebook icon-wide"></i> </a>
#  <a href="http://www.linkedin.com/shareArticle?mini=true&url=https%3A%2F%2Fwww.emploitic.com%2F%2Foffres-d-emploi%2Foffre-d-emploi%2Falgerie%2Falger%2F10076646-responsable-entrepot-sous-douane&title=Responsable Entrepôt sous douane" class="jbshare"><i class="fa fa-linkedin icon-wide"></i> </a>
#  <a href="http://twitter.com/home?status=https%3A%2F%2Fwww.emploitic.com%2F%2Foffres-d-emploi%2Foffre-d-emploi%2Falgerie%2Falger%2F10076646-responsable-entrepot-sous-douane&title=Responsable Entrepôt sous douane" class="jbshare"><i class="fa fa-twitter icon-wide"></i> </a>
#
#  <script>
#      jQuery(document).ready(function(){
#      	jQuery('.jbshare').click(function(){
#      		var url = this.href;
#      		window.open(url,'popUpWindow','height=375px,width=500px,left=300,top=200,resizable=yes,scrollbars=yes,toolbar=no,menubar=no,location=no,directories=no,status=no');return false;
#      	})
#      });
#  </script>            </span>
#          </li>
#  	</ul>-->
#  <div class="row-fluid job-details pointer">
#  <div class="bloc-right" onclick="document.location.href = 'https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/10076646-responsable-entrepot-sous-douane'; return false">
#  <div class="left-bloc text-center" itemprop="logo" itemtype="http://schema.org/Organization">
#  <img alt="Entreprise anonyme - Responsable Entrepôt sous douane" class="has-radius" height="50" src="https://www.emploitic.com/attachments/company_logo/logo_5512049_large.jpg" width="80"/>
#  </div>
#  <div class="row-fluid">
#  <a href="https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/10076646-responsable-entrepot-sous-douane" title="Responsable Entrepôt sous douane">
# ...
#  <!-- <div>
#               <a class="btn btn-small btn-color-a" href="/" title=""></a>
#              </div> -->
#  </div>
#  </div>
#  </li>,
#  <li class="separator-bot">
#  <!--<ul class="share-list hidden-phone">
#  		<li class="share-featured" onClick="" data-toggle="modal" data-target="#loginModal"><i class="fa fa-star"></i><span class="text">Sauvegarder</span></li>
#                  <li class="share-mail"><span class="text"><a class="color-a" href="mailto:?subject=Annonce consultée sur Emploitic.com - Sales Supervisor canal Gros&body=Bonjour,%0D%0A%0D%0AVoici une annonce d’Emploitic.com qui me semble intéressante : Sales Supervisor canal Gros : https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/10076205-sales-supervisor-canal-gros">Envoyer par mail</a></span><i class="fa fa-envelope-o"></i></li>
#          <li class="share-sn">
#              <i class="fa fa-mail-forward"></i>
#              <span class="text">
#                  <a href="http://www.facebook.com/sharer/sharer.php?s=100&p[url]=https%3A%2F%2Fwww.emploitic.com%2F%2Foffres-d-emploi%2Foffre-d-emploi%2Falgerie%2Falger%2F10076205-sales-supervisor-canal-gros&p[title]=Sales Supervisor canal Gros" class="jbshare"><i class="fa fa-facebook icon-wide"></i> </a>
#  <a href="http://www.linkedin.com/shareArticle?mini=true&url=https%3A%2F%2Fwww.emploitic.com%2F%2Foffres-d-emploi%2Foffre-d-emploi%2Falgerie%2Falger%2F10076205-sales-supervisor-canal-gros&title=Sales Supervisor canal Gros" class="jbshare"><i class="fa fa-linkedin icon-wide"></i> </a>
#  <a href="http://twitter.com/home?status=https%3A%2F%2Fwww.emploitic.com%2F%2Foffres-d-emploi%2Foffre-d-emploi%2Falgerie%2Falger%2F10076205-sales-supervisor-canal-gros&title=Sales Supervisor canal Gros" class="jbshare"><i class="fa fa-twitter icon-wide"></i> </a>
#
#  <script>
#      jQuery(document).ready(function(){
#      	jQuery('.jbshare').click(function(){
#      		var url = this.href;
#      		window.open(url,'popUpWindow','height=375px,width=500px,left=300,top=200,resizable=yes,scrollbars=yes,toolbar=no,menubar=no,location=no,directories=no,status=no');return false;
#      	})
#      });
#  </script>            </span>
#          </li>
#  	</ul>-->
#  <div class="row-fluid job-details pointer">
#  <div class="bloc-right" onclick="document.location.href = 'https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/10076205-sales-supervisor-canal-gros'; return false">
#  <div class="left-bloc text-center" itemprop="logo" itemtype="http://schema.org/Organization">
#  <img alt="Sarl Draco - Sales Supervisor canal Gros" class="has-radius" height="50" src="https://www.emploitic.com/attachments/company_logo/logo_5512098_large.jpg" width="80"/>
#  </div>
#  <div class="row-fluid">
#  <a href="https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/10076205-sales-supervisor-canal-gros" title="Sales Supervisor canal Gros">
#  <h2 class="ellipsis row-fluid">
#                          Sales Supervisor canal Gros                    </h2>
#  </a>
#  <div class="contact">
#  <h6 class="ellipsis"><span>Sarl Draco</span></h6>
#  </div>
#  </div>
#  </div>
#  <div class="row-fluid" onclick="document.location.href = 'https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/10076205-sales-supervisor-canal-gros'; return false">
#  <div class="bloc-bottom phone-text-small">
#  <span class="pull-left"><span class="spaced-right"><i class="fa fa-map-marker icon-left"></i>Alger, Algérie</span></span>
#  <span class="spaced-right pull-left"><i class="fa fa-clock-o icon-left"></i> Hier</span>
#  <span class="spaced-right phone-display-blok"><i class="fa fa-bookmark icon-left"></i> Manager / Responsable département (<span>3 à 5 ans</span>)</span>
#  </div>
#  </div>
#  <div class="right-bloc hidden-phone">
#  <a class="btn btn-iconed external-link" href="https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/10076205-sales-supervisor-canal-gros" target="_blank" title="Sales Supervisor canal Gros"><i class="fa fa-external-link"></i></a>
#  <!-- <div>
#               <a class="btn btn-small btn-color-a" href="/" title=""></a>
#              </div> -->
#  </div>
#  </div>
#  </li>,
#  <li class="separator-bot">
#  <!--<ul class="share-list hidden-phone">
#  		<li class="share-featured" onClick="" data-toggle="modal" data-target="#loginModal"><i class="fa fa-star"></i><span class="text">Sauvegarder</span></li>
#                  <li class="share-mail"><span class="text"><a class="color-a" href="mailto:?subject=Annonce consultée sur Emploitic.com - Responsable Juridique&body=Bonjour,%0D%0A%0D%0AVoici une annonce d’Emploitic.com qui me semble intéressante : Responsable Juridique : https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/10076642-responsable-juridique">Envoyer par mail</a></span><i class="fa fa-envelope-o"></i></li>
#          <li class="share-sn">
#              <i class="fa fa-mail-forward"></i>
#              <span class="text">
#                  <a href="http://www.facebook.com/sharer/sharer.php?s=100&p[url]=https%3A%2F%2Fwww.emploitic.com%2F%2Foffres-d-emploi%2Foffre-d-emploi%2Falgerie%2Falger%2F10076642-responsable-juridique&p[title]=Responsable Juridique" class="jbshare"><i class="fa fa-facebook icon-wide"></i> </a>
#  <a href="http://www.linkedin.com/shareArticle?mini=true&url=https%3A%2F%2Fwww.emploitic.com%2F%2Foffres-d-emploi%2Foffre-d-emploi%2Falgerie%2Falger%2F10076642-responsable-juridique&title=Responsable Juridique" class="jbshare"><i class="fa fa-linkedin icon-wide"></i> </a>
#  <a href="http://twitter.com/home?status=https%3A%2F%2Fwww.emploitic.com%2F%2Foffres-d-emploi%2Foffre-d-emploi%2Falgerie%2Falger%2F10076642-responsable-juridique&title=Responsable Juridique" class="jbshare"><i class="fa fa-twitter icon-wide"></i> </a>
#
#  <script>
#      jQuery(document).ready(function(){
#      	jQuery('.jbshare').click(function(){
#      		var url = this.href;
#      		window.open(url,'popUpWindow','height=375px,width=500px,left=300,top=200,resizable=yes,scrollbars=yes,toolbar=no,menubar=no,location=no,directories=no,status=no');return false;
#      	})
#      });
#  </script>            </span>
#          </li>
#  	</ul>-->
#  <div class="row-fluid job-details pointer">
#  <div class="bloc-right" onclick="document.location.href = 'https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/10076642-responsable-juridique'; return false">
#  <div class="left-bloc text-center" itemprop="logo" itemtype="http://schema.org/Organization">
#  <img alt="Hamoud Boualem - Responsable Juridique" class="has-radius" height="50" src="https://www.emploitic.com/attachments/company_logo/logo_5512031_large.jpg" width="80"/>
#  </div>
#  <div class="row-fluid">
#  <a href="https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/10076642-responsable-juridique" title="Responsable Juridique">
#  <h2 class="ellipsis row-fluid">
#                          Responsable Juridique                    </h2>
#  </a>
#  <div class="contact">
#  <h6 class="ellipsis"><span>Hamoud Boualem</span></h6>
#  </div>
#  </div>
#  </div>
#  <div class="row-fluid" onclick="document.location.href = 'https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/10076642-responsable-juridique'; return false">
#  <div class="bloc-bottom phone-text-small">
#  <span class="pull-left"><span class="spaced-right"><i class="fa fa-map-marker icon-left"></i>Alger, Algérie</span></span>
#  <span class="spaced-right pull-left"><i class="fa fa-clock-o icon-left"></i> Hier</span>
#  <span class="spaced-right phone-display-blok"><i class="fa fa-bookmark icon-left"></i> Manager / Responsable département (<span>6 à 10 ans</span>)</span>
#  </div>
#  </div>
#  <div class="right-bloc hidden-phone">
#  <a class="btn btn-iconed external-link" href="https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/10076642-responsable-juridique" target="_blank" title="Responsable Juridique"><i class="fa fa-external-link"></i></a>
#  <!-- <div>
#               <a class="btn btn-small btn-color-a" href="/" title=""></a>
#              </div> -->
#  </div>
#  </div>
#  </li>,
#  <li class="separator-bot">
#  <!--<ul class="share-list hidden-phone">
#  		<li class="share-featured" onClick="" data-toggle="modal" data-target="#loginModal"><i class="fa fa-star"></i><span class="text">Sauvegarder</span></li>
#                  <li class="share-mail"><span class="text"><a class="color-a" href="mailto:?subject=Annonce consultée sur Emploitic.com - Ingénieur d’Etudes&body=Bonjour,%0D%0A%0D%0AVoici une annonce d’Emploitic.com qui me semble intéressante : Ingénieur d’Etudes : https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/10076640-ingenieur-d-etudes">Envoyer par mail</a></span><i class="fa fa-envelope-o"></i></li>
#          <li class="share-sn">
#              <i class="fa fa-mail-forward"></i>
#              <span class="text">
#                  <a href="http://www.facebook.com/sharer/sharer.php?s=100&p[url]=https%3A%2F%2Fwww.emploitic.com%2F%2Foffres-d-emploi%2Foffre-d-emploi%2Falgerie%2Falger%2F10076640-ingenieur-d-etudes&p[title]=Ingénieur d’Etudes" class="jbshare"><i class="fa fa-facebook icon-wide"></i> </a>
#  <a href="http://www.linkedin.com/shareArticle?mini=true&url=https%3A%2F%2Fwww.emploitic.com%2F%2Foffres-d-emploi%2Foffre-d-emploi%2Falgerie%2Falger%2F10076640-ingenieur-d-etudes&title=Ingénieur d’Etudes" class="jbshare"><i class="fa fa-linkedin icon-wide"></i> </a>
#  <a href="http://twitter.com/home?status=https%3A%2F%2Fwww.emploitic.com%2F%2Foffres-d-emploi%2Foffre-d-emploi%2Falgerie%2Falger%2F10076640-ingenieur-d-etudes&title=Ingénieur d’Etudes" class="jbshare"><i class="fa fa-twitter icon-wide"></i> </a>
#
#  <script>
#      jQuery(document).ready(function(){
#      	jQuery('.jbshare').click(function(){
#      		var url = this.href;
#      		window.open(url,'popUpWindow','height=375px,width=500px,left=300,top=200,resizable=yes,scrollbars=yes,toolbar=no,menubar=no,location=no,directories=no,status=no');return false;
#      	})
#      });
#  </script>            </span>
#          </li>
#  	</ul>-->
#  <div class="row-fluid job-details pointer">
#  <div class="bloc-right" onclick="document.location.href = 'https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/10076640-ingenieur-d-etudes'; return false">
#  <div class="left-bloc text-center" itemprop="logo" itemtype="http://schema.org/Organization">
#  <img alt="Entreprise anonyme - Ingénieur d’Etudes" class="has-radius" height="50" src="https://www.emploitic.com/attachments/company_logo/logo_5512044_large.jpg" width="80"/>
#  </div>
#  <div class="row-fluid">
#  <a href="https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/10076640-ingenieur-d-etudes" title="Ingénieur d’Etudes">
#  <h2 class="ellipsis row-fluid">
#                          Ingénieur d’Etudes                    </h2>
#  </a>
#  <div class="contact">
#  <h6 class="ellipsis"><span>Entreprise anonyme</span></h6>
#  </div>
#  </div>
#  </div>
#  <div class="row-fluid" onclick="document.location.href = 'https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/10076640-ingenieur-d-etudes'; return false">
#  <div class="bloc-bottom phone-text-small">
#  <span class="pull-left"><span class="spaced-right"><i class="fa fa-map-marker icon-left"></i>Alger, Algérie</span></span>
#  <span class="spaced-right pull-left"><i class="fa fa-clock-o icon-left"></i> Hier</span>
#  <span class="spaced-right phone-display-blok"><i class="fa fa-bookmark icon-left"></i> Débutant / Junior (<span>Moins d’un an</span>)</span>
#  </div>
#  </div>
#  <div class="right-bloc hidden-phone">
#  <a class="btn btn-iconed external-link" href="https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/10076640-ingenieur-d-etudes" target="_blank" title="Ingénieur d’Etudes"><i class="fa fa-external-link"></i></a>
#  <!-- <div>
#               <a class="btn btn-small btn-color-a" href="/" title=""></a>
#              </div> -->
#  </div>
#  </div>
#  </li>,
#  <li class="separator-bot">
#  <!--<ul class="share-list hidden-phone">
#  		<li class="share-featured" onClick="" data-toggle="modal" data-target="#loginModal"><i class="fa fa-star"></i><span class="text">Sauvegarder</span></li>
#                  <li class="share-mail"><span class="text"><a class="color-a" href="mailto:?subject=Annonce consultée sur Emploitic.com - Chargé des prestations sociales&body=Bonjour,%0D%0A%0D%0AVoici une annonce d’Emploitic.com qui me semble intéressante : Chargé des prestations sociales : https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/10076639-charge-des-prestations-sociales">Envoyer par mail</a></span><i class="fa fa-envelope-o"></i></li>
#          <li class="share-sn">
#              <i class="fa fa-mail-forward"></i>
#              <span class="text">
#                  <a href="http://www.facebook.com/sharer/sharer.php?s=100&p[url]=https%3A%2F%2Fwww.emploitic.com%2F%2Foffres-d-emploi%2Foffre-d-emploi%2Falgerie%2Falger%2F10076639-charge-des-prestations-sociales&p[title]=Chargé des prestations sociales" class="jbshare"><i class="fa fa-facebook icon-wide"></i> </a>
#  <a href="http://www.linkedin.com/shareArticle?mini=true&url=https%3A%2F%2Fwww.emploitic.com%2F%2Foffres-d-emploi%2Foffre-d-emploi%2Falgerie%2Falger%2F10076639-charge-des-prestations-sociales&title=Chargé des prestations sociales" class="jbshare"><i class="fa fa-linkedin icon-wide"></i> </a>
#  <a href="http://twitter.com/home?status=https%3A%2F%2Fwww.emploitic.com%2F%2Foffres-d-emploi%2Foffre-d-emploi%2Falgerie%2Falger%2F10076639-charge-des-prestations-sociales&title=Chargé des prestations sociales" class="jbshare"><i class="fa fa-twitter icon-wide"></i> </a>
#
#  <script>
#      jQuery(document).ready(function(){
#      	jQuery('.jbshare').click(function(){
#      		var url = this.href;
#      		window.open(url,'popUpWindow','height=375px,width=500px,left=300,top=200,resizable=yes,scrollbars=yes,toolbar=no,menubar=no,location=no,directories=no,status=no');return false;
#      	})
#      });
#  </script>            </span>
#          </li>
#  	</ul>-->
#  <div class="row-fluid job-details pointer">
#  <div class="bloc-right" onclick="document.location.href = 'https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/10076639-charge-des-prestations-sociales'; return false">
#  <div class="left-bloc text-center" itemprop="logo" itemtype="http://schema.org/Organization">
#  <img alt="Entreprise anonyme - Chargé des prestations sociales" class="has-radius" height="50" src="https://www.emploitic.com/attachments/company_logo/logo_5512011_large.jpg" width="80"/>
#  </div>
#  <div class="row-fluid">
#  <a href="https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/10076639-charge-des-prestations-sociales" title="Chargé des prestations sociales">
#  <h2 class="ellipsis row-fluid">
#                          Chargé des prestations sociales                    </h2>
#  </a>
#  <div class="contact">
#  <h6 class="ellipsis"><span>Entreprise anonyme</span></h6>
#  </div>
#  </div>
#  </div>
#  <div class="row-fluid" onclick="document.location.href = 'https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/10076639-charge-des-prestations-sociales'; return false">
#  <div class="bloc-bottom phone-text-small">
#  <span class="pull-left"><span class="spaced-right"><i class="fa fa-map-marker icon-left"></i>Alger, Algérie</span></span>
#  <span class="spaced-right pull-left"><i class="fa fa-clock-o icon-left"></i> Hier</span>
#  <span class="spaced-right phone-display-blok"><i class="fa fa-bookmark icon-left"></i> Confirmé / Expérimenté (<span>6 à 10 ans</span>)</span>
#  </div>
#  </div>
#  <div class="right-bloc hidden-phone">
#  <a class="btn btn-iconed external-link" href="https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/10076639-charge-des-prestations-sociales" target="_blank" title="Chargé des prestations sociales"><i class="fa fa-external-link"></i></a>
#  <!-- <div>
#               <a class="btn btn-small btn-color-a" href="/" title=""></a>
#              </div> -->
#  </div>
#  </div>
#  </li>]

# %%
soup = BeautifulSoup(html_text, 'html.parser')
job = soup.find('li', class_ ='separator-bot')

# %%
job_name = job.find('h2', class_ = 'ellipsis row-fluid').text.replace('\n ','').replace(' ','')
job_name
# Out:
# 'CoordinateurTrésorerieetRelationsBancaires'

# %%
company_name = job.find('h6', class_ = 'ellipsis').text
company_name
# Out:
# 'Entreprise anonyme'

# %%
work_shift_experience = job.find('span', class_ ='spaced-right phone-display-blok').text
work_shift_experience
# Out:
# " Responsable d'équipe (Plus de 10 ans)"

# %%
localisation = job.find('span', class_ ='spaced-right').text
localisation
# Out:
# 'Bab El Oued, Alger, Algérie...'

# %%
publish_date= job.find('span', class_ ='spaced-right pull-left').text
publish_date
# Out:
# " Aujourd'hui"

# %%
print(f'''
company name: {company_name}
job name: {job_name}
work shift and experience: {work_shift_experience}
localisation: {localisation}
publish date: {publish_date}
      ''')
# Out:
# company name: Entreprise anonyme
# job name: CoordinateurTrésorerieetRelationsBancaires
# work shift and experience:  Responsable d'équipe (Plus de 10 ans)
# localisation: Bab El Oued, Alger, Algérie...
# publish date:  Aujourd'hui

# %% [markdown]
# take all jobs in first page

# %%
# def find_jobs():  
soup = BeautifulSoup(html_text, 'html.parser')
jobs = soup.find_all('li', class_ ='separator-bot')
for job in jobs:
            job_name = job.find('h2', class_ = 'ellipsis row-fluid').text.replace('\n ','').replace(' ','')
            company_name = job.find('h6', class_ = 'ellipsis').text
            work_shift_experience = job.find('span', class_ ='spaced-right phone-display-blok').text
            localisation = job.find('span', class_ ='spaced-right').text
            publish_date= job.find('span', class_ ='spaced-right pull-left').text
            more_info_link = job.div.a['href']
            

            print(f"company name: {company_name}")
            print(f"job name: {job_name}")
            print(f"work shift and experience: {work_shift_experience}")
            print(f"localisation: {localisation}")
            print(f"publish date: {publish_date}")
            print(f"more_info: {more_info_link}")
        # Access the linked page and extract additional information
            linked_page_content = requests.get(more_info_link, headers=headers).text
            linked_page_soup = BeautifulSoup(linked_page_content, 'html.parser')
            
            # Extract additional information from the linked page
            additional_info = linked_page_soup.find('div', class_='content separator-top')
            print(f"additional information: {additional_info}")

            print(' ')

# if __name__ == '__main__':
#     while True:
#         find_jobs()  
#         time_wait = 10    
#         print(f'Waiting {time_wait} minutes....')
#         time.sleep(time_wait * 60)
# Out:
# company name: Entreprise anonyme
# job name: CoordinateurTrésorerieetRelationsBancaires
# work shift and experience:  Responsable d'équipe (Plus de 10 ans)
# localisation: Bab El Oued, Alger, Algérie...
# publish date:  Aujourd'hui
# more_info: https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/bab-el-oued/10076659-coordinateur-tresorerie-et-relations-bancaires
# additional information: None
#
# company name: eTalent Solutions
# job name: DirecteurdesRessourcesHumaines
# work shift and experience:  Cadre dirigeant (Plus de 10 ans)
# localisation: Alger, Algérie
# publish date:  Hier
# more_info: https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/10076658-directeur-des-ressources-humaines
# additional information: <div class="content separator-top">
# <div class="spaced details-description">
# <p>eTalent recrute pour l'un de ses clients : </p><p><div style="text-align: center;"><b>Un Directeur des ressources Humaines </b></div><div style="text-align: center;"><br/></div><p>  Le DRH sera chargé de diriger et de superviser toutes les fonctions des ressources humaines de l'entreprise, y compris le recrutement, la formation, la gestion de la performance, la paie, les avantages sociaux, les relations avec les employés et la conformité réglementaire.</p><p><b>Responsabilités Principales</b> : </p><p>- Définir la vision stratégique des ressources humaines et diriger sa mise en œuvre. </p><p>- Élaborer et superviser des programmes efficaces de recrutement, de formation, de développement, de rétention et de succession. </p><p>- Gérer les relations avec les instances représentatives du personnel. </p><p> - Veiller à la conformité avec toutes les lois et réglementations en matière de travail. </p><p> - Superviser l'administration de la paie et des avantages sociaux. </p><p> - Analyser et améliorer les structures organisationnelles. </p><p>- Préparer le budget RH et en assurer le suivi.</p><p><b>Compétences Requises</b> : </p><p> - Connaissance approfondie des lois et réglementations en matière de travail. </p><p> - Fortes compétences en leadership. </p><p>- Excellentes capacités de communication, d'écoute et de résolution de conflits. </p><p>- Aptitude à analyser des situations complexes. </p><p>- Maîtrise des systèmes d'information RH, des logiciels de paie et des outils analytiques. </p><p><b>Profil recherché </b>: </p><p>- Diplôme de niveau Master en Ressources Humaines, Droit du travail ou domaine similaire. </p><p>- Au moins 10 ans d'expérience en gestion des ressources humaines.</p><p>- Vision stratégique et capacité à aligner les stratégies RH avec les objectifs d'affaires. </p><p>- Adaptabilité et aptitude à travailler dans un environnement dynamique. </p><p>- Intégrité et éthique dans toutes les actions.  <br/></p><ul> </ul></p> </div>
# </div>
#
# company name: Sarl Somafe
# job name: Chefd'AntenneCommercial
# work shift and experience:  Manager / Responsable département (Plus de 10 ans)
# localisation: Oran, Oran, Algérie
# publish date:  Hier
# more_info: https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/oran/oran/10074852-chef-d-antenne-commercial
# additional information: <div class="content separator-top">
# <div class="spaced details-description">
# <p><span style="font-size: 1rem;"><b><u>Missions du poste:</u></b></span><br/></p><ul><li><p>Est chargé de développer le réseau commercial dans un périmètre donné.</p></li><li>Anime, coordonne et dirige une équipe de commerciaux chargés de la vente et la distribution des fournitures et matériels électriques.</li><li>Prospecte les clients potentiels (Distributeur; installateurs; grossistes et clients finaux)</li><li>Assiste les Cadres commerciaux lorsque les termes de la négociation dépassent leur champ de compétences notamment au sujet des rabais, des ristournes et des niveaux de crédit.</li><li>Oriente les clients pour la demande en équipements assemblés en atelier de montage.</li><li>Gère la partie administrative et financière + stocks de l’antenne.</li><li>Réalise l’inventaire de l’antenne tournant ou en fin d’exercice.</li></ul><p><br/></p><b><u>Responsabilités:</u></b><ul><li>Sur la bonne gestion de l’antenne.</li><li>Sur l’atteinte des objectifs en matière de chiffre d’affaires à réaliser.</li><li>Sur l’organisation et le suivi de la relation clientèle.</li></ul><p><br/></p>Profil recherché:<ul><li>Universitaire en sciences commerciales et/ou électrotechnique.</li><li>Expérience +05 ans dans un poste similaire.</li><li>Vaste connaissance du marché de l'électricité dans la région de l'OUEST.</li><li>Grand esprit de communication, négociation.</li><li>Apte et libre de tout engagement.</li><li>Véhiculé souhaitable.</li></ul><p><br/></p><b><u>Avantages du poste:</u></b><ul><li>Salaire négociable.</li><li>Prime et variable.</li></ul><p> <br/></p> </div>
# </div>
#
# company name: Entreprise anonyme
# job name: ResponsableMaintenanceAuxiliaire
# work shift and experience:  Responsable d'équipe (6 à 10 ans)
# localisation: Alger, Algérie
# publish date:  Hier
# more_info: https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/10076657-responsable-maintenance-auxiliaire
# additional information: None
#
# company name: Entreprise anonyme
# job name: coordinatureQHSE
# work shift and experience:  Responsable d'équipe (6 à 10 ans)
# localisation: Bouira, Algérie
# publish date:  Hier
# more_info: https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/bouira/10076656-coordinature-qhse
# additional information: <div class="content separator-top">
# <div class="spaced details-description">
# <p> <br/></p> <p><u>M</u><u>issions<b>: </b></u></p> <p>Planifier, mettre en œuvre et décliner la   démarche santé sécurité au travail et environnement à l’ensemble des   processus de  l'entreprise </p> <p>·           Faire évoluer la culture QHSE, dans un souci   d'amélioration continue en intégrant les exigences réglementaires et   clients ;</p> <p>·           Préparer et planifier les programmes de   formations, sensibilisations relative au processus HSE pour une   meilleure réactivité ;</p> <p>·           Accompagner les équipes QHSE régionaux dans   le déploiement et l’atteinte des objectifs QHSE, le suivi des actions et l’évaluation   de leurs efficacités ; </p> <p>·           Participer à l’identification et à la   rédaction des informations documentées relatives au processus HSE ; </p> <p>·           Collaborer avec les équipes opérationnelles pour   la réalisation des analyses des risques par activité et par site;</p> <p>·           Consolider les plans d’actions des   différentes régions issus des réclamations clients et non-conformité relative   à la prestation de service, CPHS, inspections, contrôles et audits (Interne   et Externe);</p> <p>·           Assurer une veille réglementaire SST relative   aux activités de l'entreprise  ;</p> <p>·           Apporter des conseils et assistance   technique pour se conformer à la réglementation ;</p> <p>·           Planifier, programmer et assister les   superviseurs QHSE lors des audits internes et les audits clients ;</p> <p>·           Planifier, conduire et participer à la   réalisation du planning des exercices de simulation en collaboration   avec les Superviseurs QHSE ;</p> <p>·           Veiller sur le bon fonctionnement des systèmes de   protections collectives en collaboration avec les équipes techniques;</p> <p>·           Animer les instances mensuelles et trimestrielles   avec les superviseurs QHSE, les équipes opérationnelles;</p> <p>·           Valider les rapports d’enquête d’accident,   d’incident, d’investigation, d’inspection et d’exercice de simulation avant   diffusion ;</p> <p>·           Assurer la mise en place des consignes de   sécurité au poste de travail et les fiches préventives des risques en   collaboration avec les équipes opérationnelles ;</p> <p>·           Assurer le Reporting régulier auprès du   Directeur QHSE via le tableau de bord QHSE </p> <p><u> les pricipales compétences </u></p><p>·         Maitrise de la norme ISO 9001 - ISO 14001- ISO 45001- ISO 19011</p><p><u><br/></u> </p><p>·         Maitrise les techniques d’audit relatif au SST</p><p><u><br/></u> </p><p>·         Maitrise les méthodes de résolutions des problèmes liés au processus HSE </p><p><u><br/></u> </p><p>·         Maitrise les techniques d’évaluation des risques professionnels</p><p><u><br/></u> </p><p>·         Maitrise les exigences légales, réglementaires et normative en matière de santé et de sécurité au travail  </p><p><u><br/></u> </p><p>·         Avoir une capacité d'analyse, de conseil et de communication avec les équipes opérationnelles</p><p><u><br/></u> </p><p>·         Etre rigoureux et sérieux dans la réalisation des activités </p><p><u><br/></u> </p><p>·         Très bonne maitrise de l’outil informatique, </p><p><u><br/></u> </p><p>·         Avoir une expérience dans le domaine du transport et la logistique est un plus </p><p><u><br/></u> </p> <p> <br/></p> </div>
# </div>
#
# company name: Entreprise anonyme
# job name: CadrePlanning
# work shift and experience:  Responsable d'équipe (Plus de 10 ans)
# localisation: Alger, Algérie
# publish date:  Hier
# more_info: https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/10076653-cadre-planning
# additional information: None
#
# company name: Entreprise anonyme
# job name: ResponsableMaintenanceenginsetcamions
# work shift and experience:  Responsable d'équipe (6 à 10 ans)
# localisation: Alger, Algérie
# publish date:  Hier
# more_info: https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/10076651-responsable-maintenance-engins-et-camions
# additional information: None
#
# company name: Entreprise anonyme
# job name: ResponsableEntrepot
# work shift and experience:  Responsable d'équipe (6 à 10 ans)
# localisation: Alger, Algérie
# publish date:  Hier
# more_info: https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/10076650-responsable-entrepot
# additional information: None
#
# company name: Entreprise anonyme
# job name: UneAssistantedeDirectionGénérale(AssistanteauprèsduPDGGroupe)
# work shift and experience:  Confirmé / Expérimenté (3 à 5 ans)
# localisation: Alger Centre, Alger, Algérie
# publish date:  Hier
# more_info: https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/alger-centre/10076649-une-assistante-de-direction-generale-assistante-aupres-du-pdg-groupe
# additional information: None
#
# company name: Pharmalliance
# job name: DéléguéPharmaceutique-BATNA-
# work shift and experience:  Confirmé / Expérimenté (3 à 5 ans)
# localisation: Batna, Algérie
# publish date:  Hier
# more_info: https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/batna/10076648-delegue-pharmaceutique-batna
# additional information: <div class="content separator-top">
# <div class="spaced details-description">
# <h3 class="spaced" style="color: #333;"><span style="font-size: 1rem; color: rgb(0, 0, 0);"><br/></span></h3><h3 class="spaced" style="color: #333;"><span style="font-size: 1rem; color: rgb(0, 0, 0);">Missions :
# </span></h3><ul><li><span style="font-size: 1rem; color: rgb(0, 0, 0);">Réalisation d'entretiens d'information, de promotion et de conseil auprès des professionnels de santé.
# </span></li><li><span style="font-size: 1rem; color: rgb(0, 0, 0);">Réponse à leurs questions sur un ou plusieurs produits et services (caractéristiques, contre-indications, avantages différentiels).
# </span></li><li><span style="font-size: 1rem; color: rgb(0, 0, 0);">Organisation et animation d'actions de communication professionnelle (réunions professionnelles, formation médicale continue, universitaire, congrès...) éventuellement.
# </span></li><li><span style="font-size: 1rem; color: rgb(0, 0, 0);">Veille concurrentielle et remontée des informations auprès de sa hiérarchie.
# </span></li></ul><div><span style="font-size: 1rem; color: rgb(0, 0, 0);">
# </span></div><div><span style="font-size: 1rem; color: rgb(0, 0, 0);">
# </span></div><div><span style="font-size: 1rem; color: rgb(0, 0, 0);"><br/></span></div><h3 class="dropdown-item"><span style="font-size: 1rem; color: rgb(0, 0, 0);">Profil Recherché :</span></h3><ul><li><span style="font-size: 1rem; color: rgb(0, 0, 0);">Compétences en communication, en techniques de vente et négociation.
# </span></li><li><span style="font-size: 1rem; color: rgb(0, 0, 0);">Maîtrise parfaite de la langue française.
# </span></li><li><span style="font-size: 1rem; color: rgb(0, 0, 0);">Apte aux déplacements sur le territoire national</span></li><li><font color="#000000">véhiculé</font><br/></li>
# </ul> </div>
# </div>
#
# company name: Entreprise anonyme
# job name: ResponsableEntrepôtsousdouane
# work shift and experience:  Responsable d'équipe (6 à 10 ans)
# localisation: Alger, Algérie
# publish date:  Hier
# more_info: https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/10076647-responsable-entrepot-sous-douane
# additional information: None
#
# company name: Entreprise anonyme
# job name: ResponsableEntrepôtsousdouane
# work shift and experience:  Responsable d'équipe (6 à 10 ans)
# localisation: Alger, Algérie
# publish date:  Hier
# more_info: https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/10076646-responsable-entrepot-sous-douane
# additional information: None
#
# company name: ETAC SPA
# job name: IngénieurenSystèmesd'Information
# work shift and experience:  Confirmé / Expérimenté (3 à 5 ans)
# localisation: Alger, Algérie
# publish date:  Hier
# more_info: https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/10076645-ingenieur-en-systemes-d-information
# additional information: <div class="content separator-top">
# <div class="spaced details-description">
# <p> <u><b>Présentation de l’entreprise </b></u>:</p><p>L’ETAC, Entreprise  de Transport Algérien par Câbles, est une Joint-venture créée fin 2014  en partenariat avec POMA. L'ETAC a pour mission l’exploitation, la  maintenance, et la formation dans le domaine des remontées mécaniques .  L’ETAC est présente sur le territoire national et compte actuellement  plus de 700 collaborateurs.</p><p><b><u>Missions:</u></b></p><p><b>Mission   1 :  </b><b> Analyse des besoins technique des projets SI</b></p> <p>-         Recueille l’information nécessaire et formalise la définition des   besoins,</p> <p>-         Etudie les besoins d’équipements logiciels et rédige le cahier des   prescriptions (Fonctionnel, matériel, sécurité des données ou impact sur les   systèmes existants),</p> <p>-         Propose des solutions techniques standards ou à concevoir </p> <p> <b>Mission   2 : </b><b> </b><b> </b><b> Met en place et intègre des solutions logicielles   retenues</b> </p><p>-       S’assure du déploiement des   solutions retenues : analyse, installation et adaptation (paramétrage) des   logiciels de base sélectionnés aux besoins des utilisateurs.</p> <p>-       Teste les systèmes mis en place et   veiller à la compatibilité des éléments entre eux, et de la conformité au   cahier des prescriptions,</p> <p>-       Rédige et met à jour la documentation   de paramétrage et d’utilisation.</p> <p>-         Participe à la formation des utilisateurs.</p> <p> <b>Mission   3 : </b><b> Administre et maintient les systèmes   Informatiques en vue d’assurer leur continuité de service</b> </p><p>-       Gère les ressources Logiciels et   les comptes utilisateurs.</p> <p>-       Diagnostique les pannes et les   dysfonctionnements liés aux logiciels.</p> <p>-       Répare ou fait réparer les pannes   et les dysfonctionnements logiciels.</p> <p>-       Assure la résolution des problèmes   du premier niveau</p> <p>-       S’assure de la résolution des   problèmes des niveaux plus complexes en lien avec les fournisseurs.</p> <p>-       Assure une maintenance évolutive et   corrective en fonction des grandes évolutions technologiques (notamment les   changements de versions).</p> <p>-       Mesure et optimise la disponibilité   et les performances des systèmes.</p> <p>-       Veille à la sécurité et à la   fiabilité des systèmes.</p> <p>-       Assure une veille technologique   pour garantir l’optimisation des ressources systèmes de l’entreprise.</p><p><u><b>Exigences du Poste:</b></u></p><ul type="disc"> <li>Justifier d’une      expérience avec les ERP (Spécialement MS Dynamics Nav) et disposer de      compétences dans un domaine métier (Finances, Comptabilité, Achats,      Projet, Gestion du stock, Gestion de Production);</li> <li>Maitrise de la      programmation orienté objet, ses exigences et ses contraintes;</li> <li>Maitrise de quelques      outils de reporting tels que Power BI, Crystal Report;</li> <li>Expérience en bases de      données : MS sql server, MySQL, Oracle, Mongodb ;</li> <li>Connaissance en      utilisation des différents logiciels du pack Office 365 Business (      Exchange, Sharepoint, PowerApps, Power Automate, …) .</li> </ul><p><u><b><br/></b></u></p><p><br/></p> <p> </p> </div>
# </div>
#
# company name: Genisoft Informatique
# job name: Informaticien(enne)
# work shift and experience:  Débutant / Junior (3 à 5 ans)
# localisation: Alger, Algérie
# publish date:  Hier
# more_info: https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/10076068-informaticien-enne
# additional information: <div class="content separator-top">
# <div class="spaced details-description">
# <p>Nous vous informons que Genisoft Informatique est à la recherche d'un informaticien (enne)<br/></p><p><b><u><br/></u></b></p> <br/><h3 class="">Description du poste :   </h3><ul type="disc"><li>Assister les      clients </li> <li>Assurer les      formations sur les logiciels Genisoft</li> </ul><p><b><u><br/></u></b></p><h3 class="">Conditions :</h3><ul type="disc"><li>Titulaire d'un      diplôme de  TS en informatique , Master ou Ingénieur en informatique.</li> <li>Ayant      connaissance sur les langages de programmation : Python, PHP, Delphi,      HTML, CSS, JAVASCRIPT; .......</li> <li>Bonne      communication écrite et orale.</li> <li>Lieu de      travail : Chevalley (Alger). </li> </ul><p> <br/></p> </div>
# </div>
#
# company name: Eurl Chemlal Confection
# job name: Financier
# work shift and experience:  Confirmé / Expérimenté (3 à 5 ans)
# localisation: Algérie
# publish date:  Hier
# more_info: https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/10076652-financier
# additional information: <div class="content separator-top">
# <div class="spaced details-description">
# <h3 class="">  Missions : </h3><ul><li> Suivre toute la comptabilité et classement des pièces comptables de en respectant la procédure d’archivage comptable de l’entreprise. </li><li>Procéder aux imputations comptables.</li><li>Tenir à jour les différents états comptables, journaux auxiliaires, Grand livre, balance, etc.</li><li>Établir les rapprochements bancaires manuels</li><li>Procéder à l’analyse des comptes et participer aux travaux de fin d’exercice et du bilan.</li><li>Superviser l'ensemble des fonctions Financières, comptabilité, gestion, trésorerie, fiscalité et communication financière ;</li><li>Suivre la situation de la trésorerie ;</li><li>Concevoir et organiser les systèmes de contrôle des dépenses ;</li><li>Assurer la responsabilité des opérations financières de l'entreprise et notamment le recouvrement des créances et le règlement des engagements de l’entreprise ;</li><li>Coordonner la relation avec les tiers (commissaires aux comptes, banques, impôts, CNAS client, fournisseur) ;</li><li>L’établissement des déclarations fiscales et parafiscales;</li><li>Contrôler la conformité fiscale des pièces comptables achats, ventes, contrats et opérations diverses ;</li><li>Garantir l’exécution des contrats, paiement des prestataires conformément aux procédures internes en vigueur. </li><li>Suivi des modalités de la ligne de crédit, y compris les plafonds autorisés.<br/></li></ul><ul><li>Enregistrement précis des transactions liées à l'utilisation de la ligne de crédit.</li><li>Participation aux négociations avec les institutions financières pour obtenir ou renégocier des lignes de crédit.</li><li>Évaluation des conditions et des termes des contrats de crédit.</li><li>Suivi des contrats de domiciliation<br/></li></ul><br/><br/><h3 class="">Profil :</h3><ul><li>Maîtrise des procédures administratives de gestion financière et comptable  et de la fiscalité.</li><li>Maîtrise parfaitement le logiciel PC COMPTA ;</li><li>Savoir-faire remonter des informations dans le respect des procédures et les délais fixés par sa hiérarchie.</li><li>Savoir exposer régulièrement les résultats et analyses qu’il produit à son responsable hiérarchique (tableaux de bord)</li><li>Capacités d’analyse et de synthèse ;</li><li>Sens de l’anticipation, planification et organisation</li><li>Qualités relationnelles et organisationnelles avérées ;</li><li>Sens de confidentialité et discrétion</li><li>Savoir gérer les conflits, travailler en équipe,</li><li>Diplôme BAC +4/5 en Finances, Comptabilité ou équivalent ;</li><li>Entre 02 et 03 ans d’expérience dans un poste similaire</li><li>  +5 ans d'experience<br/> <br/></li></ul><br class="Apple-interchange-newline"/> <br/><ul> </ul> </div>
# </div>
#
# company name: Metal Sider
# job name: Juriste
# work shift and experience:  Confirmé / Expérimenté (3 à 5 ans)
# localisation: Oran, Algérie
# publish date:  Hier
# more_info: https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/oran/10076643-juriste
# additional information: <div class="content separator-top">
# <div class="spaced details-description">
# <h3 class="">Missions principales :</h3>
# <ul>
# <li>Assurer un rôle de conseil auprès de la Direction Générale et des structures de la société en matière de droit et contentieux.</li>
# <li>Prévenir le risque juridique et assurer une veille en la matière .</li>
# <li>Défendre les intérêts de la société devant les juridictions.</li>
# <li>Participer de manière active à l’élaboration et validation des divers contrats.</li>
# <li>Veiller à la sécurité juridique de l’entreprise,  et en défendre les intérêts de l’entreprise au cours d'opérations juridiques et financières.</li>
# <li>Représenter la société auprès des instances judiciaires et admnistratives.</li></ul>
# <h3 class="">Profil :</h3>
# <ul>
# <li>Diplômé de l’enseignement supérieur en droit.</li>
# <li>Une expérience professionnelle minimale de 5 ans sur un poste similaire.</li><li>Bonne maitrise du français.</li><li>Apte aux deplacements sur le territoire national.</li>
# </ul> </div>
# </div>
#
# company name: Sarl Draco
# job name: SalesSupervisorcanalGros
# work shift and experience:  Manager / Responsable département (3 à 5 ans)
# localisation: Alger, Algérie
# publish date:  Hier
# more_info: https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/10076205-sales-supervisor-canal-gros
# additional information: <div class="content separator-top">
# <div class="spaced details-description">
# <h3>Missions du poste :<strong> </strong></h3>
# <p><strong>1. </strong><strong>Coaching et développement</strong></p>
# <ul>
# <li>Gérer une équipe de commerciaux en charge du portefeuille gros .</li>
# <li>Participer au recrutement des commerciaux (recherches, entretiens, etc.).</li>
# <li>Accompagner, former et motiver de son équipe (à raison de 80% de son temps) afin d’atteindre les objectifs assignés.</li>
# <li>Développer et former continuellement la force de vente.</li>
# </ul>
# <p><strong>2. Réalisation des objectifs de ventes</strong></p>
# <ul>
# <li>Veiller au suivi des ventes et créances des tops clients existants .</li>
# <li>Veiller à la réalisation des objectifs qualitatifs et quantitatifs fixés par la direction commerciale.</li>
# <li>Veiller à l’exécution de la stratégie commerciale de l’entreprise.</li>
# <li>Planifier et suivre du lancement des nouveaux produits .</li>
# <li>Développer des parts de marché, du business .</li>
# </ul>
# <p><strong>3. Analyse et planification</strong></p>
# <ul>
# <li>Développer une parfaite maîtrise des produits, marques et secteurs gros.</li>
# <li>Comprendre, analyser et synthétiser la dynamique du marché, des catégories et de la concurrence.</li>
# <li>Tenir à jour son tableau de bord et garder le focus sur ces KPI</li>
# <li>Analyser les performances de son équipe et élaboration des plans d’action correctifs.</li>
# </ul>
# <p><strong>4. Base de données et Routing</strong></p>
# <ul>
# <li>Garant de la base de données clients et de la productivité de la FDV.</li>
# <li>Planifier et optimiser les itinéraires des vendeurs gros.</li>
# <li>Segmenter l’univers Point de vente par canal et selon de potentiel pour nos marques.</li>
# </ul>
# <p><strong>5. Reporting</strong></p>
# <ul>
# <li>Assurer un reporting régulier de son activité.</li>
# <li>Remontés d’information et veille concurrentielle.</li>
# </ul>
# <p><span style="text-decoration: underline;"><strong><span style="font-size: 12.16px;">Indicateurs clés de performance</span></strong></span></p>
# <ul>
# <li>
# <p style="font-size: 12.16px; display: inline !important;">Réalisation de CA vs. Objectif</p>
# </li>
# <li>Activation du portefeuille client</li>
# <li>Distribution Numérique</li>
# <li>Profondeur de la gamme</li>
# <li>CA par client</li>
# </ul>
# <h3>Profil recherché :</h3>
# <p><strong style="font-size: 12.16px;">Compétences</strong></p>
# <ul>
# <li>Orienté résultats</li>
# <li>Manager de talent</li>
# <li>Excellent commercial</li>
# <li>Diplomate et négociateur</li>
# <li>Esprit créatif et positif</li>
# </ul>
# <p><strong style="font-size: 12.16px;">Capacités</strong></p>
# <ul>
# <li>Capacité d’analyse,</li>
# <li>Capacité de synthèse,</li>
# <li>Capacité à coordonner des informations et des interlocuteurs,</li>
# <li>Capacité à prendre des responsabilités et à manager une équipe,</li>
# <li>Capacité à performer sous pression.</li>
# </ul>
# <p><strong>Qualités</strong></p>
# <ul>
# <li>Leadership et charisme,</li>
# <li>Rigueur et discipline,</li>
# <li>Aisance relationnelle,</li>
# <li>Esprit analytique et force de proposition,</li>
# <li>Sens de l’organisation.</li>
# </ul>
# <p><strong>Exigence</strong></p><ul>
# <li>Minimum de 2 à 3 ans d’expérience dans un poste similaire   </li>
# </ul>
# <p> </p>
# <p> </p> </div>
# </div>
#
# company name: Hamoud Boualem
# job name: ResponsableJuridique
# work shift and experience:  Manager / Responsable département (6 à 10 ans)
# localisation: Alger, Algérie
# publish date:  Hier
# more_info: https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/10076642-responsable-juridique
# additional information: <div class="content separator-top">
# <div class="spaced details-description">
# <p><b>                    Taches Principales</b> : </p><ul type="disc"> <li>Préparer, réviser et négocier divers contrats      commerciaux, accords de partenariat, accords de confidentialité et autres      documents juridiques.</li> <li>Collaborer      avec les équipes opérationnelles pour résoudre les litiges potentiels et      fournir un soutien dans la gestion des procédures judiciaires, le cas      échéant.</li> <li>Suivre      les développements législatifs, réglementaires et jurisprudentiels      pertinents, et s'assurer que l'entreprise est informée de toute      implication potentielle.</li> <li>Dispenser des formations internes sur les      questions juridiques et les politiques de l'entreprise, contribuant ainsi      à renforcer la conformité et la sensibilisation juridique au sein de      l'organisation.</li> <li>Travailler en étroite collaboration avec les      autres départements pour comprendre les objectifs commerciaux et fournir      des solutions juridiques alignées sur ces objectifs. </li> <li>Fournir      des conseils juridiques précis et opportuns sur un large éventail de      questions, y compris le droit des contrats, le droit des sociétés, le      droit du travail, la propriété intellectuelle, et autres domaines      pertinents.</li> <li>Assurer      la gestion des contentieux notamment ceux liés au recouvrement des      créances en prévoyant un suivi régulier aux équipes et à la hiérarchie</li></ul><p><b>Qualifications requises</b> :</p><p>·        Licence en science administrative et juridique.</p><p>·        Expérience professionnelle de 5 ans minimum dans un poste similaire</p><p>·        Excellentes compétences analytiques, de rédaction et de communication.</p><p>·        Capacité à travailler de manière autonome tout en collaborant efficacement avec différentes équipes.</p><p> <br/></p> </div>
# </div>
#
# company name: Entreprise anonyme
# job name: Ingénieurd’Etudes
# work shift and experience:  Débutant / Junior (Moins d’un an)
# localisation: Alger, Algérie
# publish date:  Hier
# more_info: https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/10076640-ingenieur-d-etudes
# additional information: None
#
# company name: Entreprise anonyme
# job name: Chargédesprestationssociales
# work shift and experience:  Confirmé / Expérimenté (6 à 10 ans)
# localisation: Alger, Algérie
# publish date:  Hier
# more_info: https://www.emploitic.com/offres-d-emploi/offre-d-emploi/algerie/alger/10076639-charge-des-prestations-sociales
# additional information: None
